# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(np.random.randn(5,4),["A","B","C","D","E"],["W","X","Y","Z"])

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[["W","Z"]]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
df["new"] = df["W"] + df["Z"]

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.210676
# B  0.651118 -0.319318 -0.848077  0.605965  1.257083
# C -2.018168  0.740122  0.528813 -0.589001 -2.607169
# D  0.188695 -0.758872 -0.933237  0.955057  1.143752
# E  0.190794  1.978757  2.605967  0.683509  0.874303

# %%
#always specify an axis, axis=1 == column
df.drop("new",axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.210676
# B  0.651118 -0.319318 -0.848077  0.605965  1.257083
# C -2.018168  0.740122  0.528813 -0.589001 -2.607169
# D  0.188695 -0.758872 -0.933237  0.955057  1.143752
# E  0.190794  1.978757  2.605967  0.683509  0.874303

# %%
#to keep tha change refference inplace=True
df.drop("new",axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
#to grab rows use loc[] (location)
df.loc["B"]
# Out:
# W    0.651118
# X   -0.319318
# Y   -0.848077
# Z    0.605965
# Name: B, dtype: float64

# %%
#to grab a row with an int - usuful when the label changes - so to grab row B f.e.:
df.iloc[1]
# Out:
# W    0.651118
# X   -0.319318
# Y   -0.848077
# Z    0.605965
# Name: B, dtype: float64

# %%
#for single or multiple value grabs use the same notation as numpy
df.loc["B","W"]
# Out:
# np.float64(0.6511179479432686)

# %%
df.loc[["A","B"],["W","Z"]]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965

# %%
### NEXT LESSON
df > 0
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
#way to extract positive values:
booldf = df > 0
booldf
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[booldf]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
#faster simpler way:
df[df>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df["W"]>0
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# Name: W, dtype: bool

# %%
df[df["W"]>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df["W"]>0]["X"]
# Out:
# A    0.628133
# B   -0.319318
# D   -0.758872
# E    1.978757
# Name: X, dtype: float64

# %%
#for multiple cnditions py's and will not work because it will try to check multiple bools in each side. Instead  use &, for or use | (shift+key b4 1)
df[(df["W"]<0) & (df["Z"]<0)]
# Out:
#           W         X         Y         Z
# C -2.018168  0.740122  0.528813 -0.589001

# %%
#extract the index:
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
#add new index, make sure the dimensions match
new_ind = "AA BB CC DD EE".split() #nice little trick to create a list fast
new_ind
# Out:
# ['AA', 'BB', 'CC', 'DD', 'EE']

# %%
df["index_2.0"] = new_ind
df
# Out:
#           W         X         Y         Z index_2.0
# A  2.706850  0.628133  0.907969  0.503826        AA
# B  0.651118 -0.319318 -0.848077  0.605965        BB
# C -2.018168  0.740122  0.528813 -0.589001        CC
# D  0.188695 -0.758872 -0.933237  0.955057        DD
# E  0.190794  1.978757  2.605967  0.683509        EE

# %%
### NEXT LESSON
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(np.random.randn(6,2),hier_index,["A","B"])
df
# Out:
#              A         B
# G1 1  1.025984 -0.156598
#    2 -0.031579  0.649826
#    3  2.154846 -0.610259
# G2 1 -0.755325 -0.346419
#    2  0.147027 -0.479448
#    3  0.558769  1.024810

# %%
df.loc["G1"]
# Out:
#           A         B
# 1  1.025984 -0.156598
# 2 -0.031579  0.649826
# 3  2.154846 -0.610259

# %%
df.loc["G1"].loc[1]
# Out:
# A    1.025984
# B   -0.156598
# Name: 1, dtype: float64

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ["Groups","Num"]
df
# Out:
#                    A         B
# Groups Num
# G1     1    1.025984 -0.156598
#        2   -0.031579  0.649826
#        3    2.154846 -0.610259
# G2     1   -0.755325 -0.346419
#        2    0.147027 -0.479448
#        3    0.558769  1.024810

# %%
#select a single value
df.loc["G1"].loc[2]["B"]
# Out:
# np.float64(0.6498258334908454)

# %%
#cross-section == .xs
df.xs(1,level="Num") #cross-section is useful to grab data from multiple places under one "tag" or subgroup
# Out:
#                A         B
# Groups
# G1      1.025984 -0.156598
# G2     -0.755325 -0.346419
